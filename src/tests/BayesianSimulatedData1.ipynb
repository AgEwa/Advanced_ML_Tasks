# %%
from src.utils.TestHelper import TestHelper

# %%
tester = TestHelper()
rho = 0.5
a = [0.1, 0.5, 1, 2, 3, 5]
test_sizes = [0.1, 0.2, 0.3, 0.4]

# %% [markdown]
# # 1. Experiment - test sizes for selected value a

# %%
tester.ylim = (0.8,1)

# %% [markdown]
# ## Schema 1

# %%
for test_size in test_sizes:
    tester.test_scheme_1(2, 100, test_size)

# %% [markdown]
# ## Schema 2

# %%
for test_size in test_sizes:
    tester.test_scheme_2(2, rho, 100, test_size)

# %% [markdown]
# ### Key observations

# %% [markdown]
# # 2. Experiment - different values a

# %%
tester.ylim = None

# %% [markdown]
# ## Schema 1

# %%
for a_i in a:
    tester.test_scheme_1(a_i, 100)

# %% [markdown]
# ## Scheme 2

# %%
for a_i in a:
    tester.test_scheme_2(a_i, rho, 100)

# %% [markdown]
# ### Key observations
