# %%
from src.utils.TestHelper import TestHelper

# %%
tester = TestHelper()
rho = 0.5
a = [0.1, 0.5, 1, 2, 3, 5]

# %% [markdown]
# # Experiment - different values of a

# %% [markdown]
# ## Schema 1

# %%
for a_i in a:
    tester.test_scheme_1(a_i, 100)

# %% [markdown]
# ## Scheme 2

# %%
for a_i in a:
    tester.test_scheme_2(a_i, rho, 100)
