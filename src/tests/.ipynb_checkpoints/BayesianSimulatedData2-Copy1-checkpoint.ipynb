# %%
from src.utils.TestHelper import TestHelper

# %%
tester = TestHelper()
a = 2
rho = [0, 0.1, 0.3, 0.5, 0.7, 0.9]
test_sizes = [0.1, 0.2, 0.3, 0.4]

# %% [markdown]
# # 1. Experiment - test sizes for selected value rho

# %%
tester.ylim = (0.8,1)

# %% [markdown]
# ## Schema 1

# %%
for test_size in test_sizes:
    tester.test_scheme_1(a, 100, test_size)

# %% [markdown]
# ## Schema 2

# %%
for test_size in test_sizes:
    tester.test_scheme_2(a, 0.5, 100, test_size)

# %% [markdown]
# ### Key observations

# %% [markdown]
# # 2. Experiment - different values a

# %%
tester.ylim = None

# %% [markdown]
# ## Schema 1

# %%
tester.test_scheme_1(a, 100)

# %% [markdown]
# ## Scheme 2

# %%
for rho_i in rho:
    tester.test_scheme_2(a, rho_i, 100)

# %% [markdown]
# ### Key observations
