# %%
from BayesianClassification.src.utils.TestHelper import TestHelper
from BayesianClassification.src.utils.Dataset import Dataset

# %%
tester = TestHelper()

# %% [markdown]
# Additionally (out of curiosity):

# %%
precisionTester = TestHelper("precision")
recallTester = TestHelper("recall")

# %% [markdown]
# # wine dataset

# %%
X, y = Dataset.load_data(44091)

# %%
print(X.shape)
print(y.shape)
# Out:
# (2554, 11)
# (2554,)

# %%
tester.test_real_data(X, y, 100)

# %% [markdown]
# ## Precision

# %%
precisionTester.test_real_data(X, y, 100)

# %% [markdown]
# ## Recall

# %%
recallTester.test_real_data(X, y, 100)

# %% [markdown]
# # MagicTelescope dataset

# %%
X, y = Dataset.load_data(44125)

# %%
print(X.shape)
print(y.shape)
# Out:
# (13376, 10)
# (13376,)

# %%
tester.test_real_data(X, y, 100)

# %%
precisionTester.test_real_data(X, y, 100)

# %%
recallTester.test_real_data(X, y, 100)

# %% [markdown]
# # pol dataset

# %%
X, y = Dataset.load_data(44122)

# %%
print(X.shape)
print(y.shape)
# Out:
# (10082, 26)
# (10082,)

# %%
tester.test_real_data(X, y, 100)

# %% [markdown]
# ## Precision

# %%
precisionTester.test_real_data(X, y, 100)

# %% [markdown]
# ## Recall

# %%
recallTester.test_real_data(X, y, 100)

# %% [markdown]
# # chscase_geyser1 dataset

# %% [markdown]
# Extra case with 2 features and decision boundary plot

# %%
X, y = Dataset.load_data(895)

# %%
print(X.shape)
print(y.shape)
# Out:
# (222, 2)
# (222,)

# %%
tester.test_real_data(X, y, 100)

# %% [markdown]
# ## Precision

# %%
precisionTester.test_real_data(X, y, 100)

# %% [markdown]
# ## Recall

# %%
recallTester.test_real_data(X, y, 100)

# %% [markdown]
# ## Decision boundaries of LDA and QDA

# %%
tester.plot_boundaries(X=X, y=y)
