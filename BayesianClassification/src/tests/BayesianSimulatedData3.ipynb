# %%
from BayesianClassification.src.utils.TestHelper import TestHelper

# %%
tester = TestHelper()
a = 2
rho = 0.5

# %% [markdown]
# # Decision Boundary in LDA and QDA

# %% [markdown]
# LDA - green, QDA - purple

# %% [markdown]
# ## Schema 1

# %%
tester.plot_boundaries(a)

# %% [markdown]
# ## Schema 2

# %%
tester.plot_boundaries(a, rho)
